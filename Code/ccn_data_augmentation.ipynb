# %%
import numpy as np
import pandas as pd
import cv2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# %%
# Path to your dataset directory
csv_directory = 'D:/Documents/Thesis/Code/DataSet/english.csv'

# List all image files in the dataset directory
data = pd.read_csv(csv_directory)

# %%
# Extract the image paths and corresponding labels
image_paths = data['image'].values
labels = data['label'].values

# %%
# Clean and preprocess label data
unique_labels = np.unique(labels)
label_mapping = {label: index for index, label in enumerate(unique_labels)}

# %%
# Map labels to numerical values
clean_labels = []
clean_image_paths = []
for i in range(len(labels)):
    try:
        label = labels[i]
        clean_labels.append(label_mapping[label])
        clean_image_paths.append(image_paths[i])
    except KeyError:
        print(f"Ignoring sample: {image_paths[i]} with label: {label}")

# %%
# Convert the labels to numerical values
labels = np.array(clean_labels)
image_paths = np.array(clean_image_paths)

# Split the dataset into training and testing sets
train_paths, test_paths, train_labels, test_labels = train_test_split(
    image_paths, labels, test_size=0.2, random_state=42)

# Preprocess the training images
train_images = []

# %%
for image_path in train_paths:
    # Read the image
    image = cv2.imread(image_path)
    
    # Validate the image
    if image is None:
        print(f"Unable to read image: {image_path}")
        continue
    
    # Resize the image to a fixed size
    image = cv2.resize(image, (32, 32))
    
    # Validate the image size
    if image.size == 0:
        print(f"Empty image: {image_path}")
        continue
    
    # Normalize the pixel values to [0, 1]
    image = image / 255.0
    
    train_images.append(image)

# %%
# Convert the training images to NumPy array
train_images = np.array(train_images)

# %%
# Preprocess the testing images
test_images = []
for image_path in test_paths:
    # Read the image
    image = cv2.imread(image_path)
    
    # Validate the image
    if image is None:
        print(f"Unable to read image: {image_path}")
        continue
    
    # Resize the image to a fixed size
    image = cv2.resize(image, (32, 32))
    
    # Validate the image size
    if image.size == 0:
        print(f"Empty image: {image_path}")
        continue
    
    # Normalize the pixel values to [0, 1]
    image = image / 255.0
    
    test_images.append(image)

# %%
# Convert the testing images to NumPy array
test_images = np.array(test_images)

# %%
# Determine the number of classes in your dataset
num_classes = len(np.unique(labels))

# %%
# Convert the labels to one-hot encoded vectors
train_labels = to_categorical(train_labels, num_classes)
test_labels = to_categorical(test_labels, num_classes)

# %%
# Build the model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(train_images, train_labels, epochs=10, batch_size=32, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 86/86 [==============================] - 3s 21ms/step - loss: 4.0407 - accuracy: 0.0488 - val_loss: 3.6448 - val_accuracy: 0.1217
# Epoch 2/10
# 86/86 [==============================] - 1s 16ms/step - loss: 2.8492 - accuracy: 0.2889 - val_loss: 2.4475 - val_accuracy: 0.3548
# Epoch 3/10
# 86/86 [==============================] - 1s 17ms/step - loss: 1.7584 - accuracy: 0.5271 - val_loss: 1.8898 - val_accuracy: 0.5147
# Epoch 4/10
# 86/86 [==============================] - 1s 16ms/step - loss: 1.2072 - accuracy: 0.6705 - val_loss: 1.7093 - val_accuracy: 0.5674
# Epoch 5/10
# 86/86 [==============================] - 1s 16ms/step - loss: 0.9304 - accuracy: 0.7379 - val_loss: 1.5407 - val_accuracy: 0.5938
# Epoch 6/10
# 86/86 [==============================] - 1s 17ms/step - loss: 0.6651 - accuracy: 0.8050 - val_loss: 1.5936 - val_accuracy: 0.6012
# Epoch 7/10
# 86/86 [==============================] - 1s 16ms/step - loss: 0.5253 - accuracy: 0.8321 - val_loss: 1.5164 - val_accuracy: 0.6261
# Epoch 8/10
# 86/86 [==============================] - 2s 19ms/step - loss: 0.3875 - accuracy: 0.8886 - val_loss: 1.6682 - val_accuracy: 0.6100
# Epoch 9/10
# 86/86 [==============================] - 1s 16ms/step - loss: 0.2788 - accuracy: 0.9223 - val_loss: 1.7025 - val_accuracy: 0.6290
# Epoch 10/10
# 86/86 [==============================] - 1s 17ms/step - loss: 0.1997 - accuracy: 0.9439 - val_loss: 1.7094 - val_accuracy: 0.6349

# %%
# Evaluate the model
loss, accuracy = model.evaluate(test_images, test_labels)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 22/22 [==============================] - 0s 20ms/step - loss: 1.7094 - accuracy: 0.6349
# Test Loss: 1.7094470262527466
# Test Accuracy: 0.6348973512649536

# %%
# Make predictions
predictions = model.predict(test_images)
# Out:
# 22/22 [==============================] - 0s 6ms/step

# %%
# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Convert one-hot encoded labels to actual labels
actual_labels = np.argmax(test_labels, axis=1)

# %%
# Display the predicted labels and actual labels
for i in range(len(predicted_labels)):
    predicted_label = predicted_labels[i]
    actual_label = actual_labels[i]
    print(f"Predicted: {predicted_label}, Actual: {actual_label}")
# Out:
# Predicted: 53, Actual: 57
# Predicted: 22, Actual: 32
# Predicted: 45, Actual: 3
# Predicted: 38, Actual: 12
# Predicted: 0, Actual: 50
# Predicted: 55, Actual: 55
# Predicted: 32, Actual: 32
# Predicted: 26, Actual: 26
# Predicted: 51, Actual: 41
# Predicted: 26, Actual: 26
# Predicted: 53, Actual: 29
# Predicted: 40, Actual: 59
# Predicted: 54, Actual: 3
# Predicted: 46, Actual: 20
# Predicted: 18, Actual: 1
# Predicted: 54, Actual: 54
# Predicted: 32, Actual: 32
# Predicted: 0, Actual: 24
# Predicted: 17, Actual: 17
# Predicted: 29, Actual: 29
# Predicted: 48, Actual: 48
# Predicted: 54, Actual: 28
# Predicted: 48, Actual: 48
# Predicted: 48, Actual: 48
# Predicted: 0, Actual: 0
# Predicted: 12, Actual: 16
# Predicted: 39, Actual: 41
# Predicted: 53, Actual: 42
# Predicted: 16, Actual: 16
# Predicted: 61, Actual: 59
# Predicted: 47, Actual: 18
# Predicted: 7, Actual: 19
# Predicted: 24, Actual: 50
# Predicted: 35, Actual: 2
# Predicted: 50, Actual: 50
# Predicted: 0, Actual: 0
# Predicted: 7, Actual: 7
# Predicted: 53, Actual: 53
# Predicted: 59, Actual: 59
# Predicted: 54, Actual: 5
# Predicted: 44, Actual: 44
# Predicted: 7, Actual: 7
# Predicted: 0, Actual: 50
# Predicted: 9, Actual: 9
# Predicted: 4, Actual: 10
# Predicted: 53, Actual: 49
# Predicted: 31, Actual: 58
# Predicted: 52, Actual: 52
# Predicted: 24, Actual: 13
# Predicted: 40, Actual: 40
# Predicted: 52, Actual: 52
# Predicted: 55, Actual: 41
# Predicted: 0, Actual: 57
# Predicted: 12, Actual: 12
# Predicted: 26, Actual: 26
# Predicted: 45, Actual: 41
# Predicted: 28, Actual: 42
# Predicted: 49, Actual: 49
# Predicted: 27, Actual: 27
# Predicted: 56, Actual: 57
# Predicted: 39, Actual: 39
# Predicted: 29, Actual: 29
# Predicted: 51, Actual: 58
# Predicted: 15, Actual: 15
# Predicted: 55, Actual: 55
# Predicted: 47, Actual: 45
# Predicted: 48, Actual: 48
# Predicted: 45, Actual: 45
# Predicted: 31, Actual: 31
# Predicted: 61, Actual: 61
# Predicted: 7, Actual: 49
# Predicted: 2, Actual: 2
# Predicted: 24, Actual: 0
# Predicted: 53, Actual: 59
# Predicted: 52, Actual: 52
# Predicted: 55, Actual: 55
# Predicted: 11, Actual: 27
# Predicted: 57, Actual: 57
# Predicted: 42, Actual: 54
# Predicted: 13, Actual: 13
# Predicted: 30, Actual: 56
# Predicted: 58, Actual: 58
# Predicted: 10, Actual: 10
# Predicted: 23, Actual: 23
# Predicted: 31, Actual: 31
# Predicted: 55, Actual: 54
# Predicted: 0, Actual: 0
# Predicted: 29, Actual: 29
# Predicted: 53, Actual: 59
# Predicted: 43, Actual: 43
# Predicted: 22, Actual: 22
# Predicted: 5, Actual: 5
# Predicted: 53, Actual: 53
# Predicted: 24, Actual: 54
# Predicted: 61, Actual: 44
# Predicted: 46, Actual: 20
# Predicted: 47, Actual: 47
# Predicted: 47, Actual: 44
# Predicted: 34, Actual: 60
# Predicted: 3, Actual: 3
# Predicted: 39, Actual: 39
# Predicted: 32, Actual: 32
# Predicted: 47, Actual: 47
# Predicted: 0, Actual: 0
# Predicted: 53, Actual: 49
# Predicted: 3, Actual: 3
# Predicted: 31, Actual: 34
# Predicted: 8, Actual: 8
# Predicted: 53, Actual: 5
# Predicted: 15, Actual: 15
# Predicted: 15, Actual: 57
# Predicted: 37, Actual: 37
# Predicted: 12, Actual: 12
# Predicted: 5, Actual: 5
# Predicted: 17, Actual: 4
# Predicted: 18, Actual: 18
# Predicted: 31, Actual: 31
# Predicted: 0, Actual: 0
# Predicted: 2, Actual: 2
# Predicted: 10, Actual: 54
# Predicted: 7, Actual: 7
# Predicted: 54, Actual: 8
# Predicted: 21, Actual: 21
# Predicted: 53, Actual: 53
# Predicted: 12, Actual: 12
# Predicted: 14, Actual: 14
# Predicted: 47, Actual: 47
# Predicted: 56, Actual: 56
# Predicted: 13, Actual: 13
# Predicted: 53, Actual: 49
# Predicted: 24, Actual: 50
# Predicted: 20, Actual: 46
# Predicted: 52, Actual: 52
# Predicted: 47, Actual: 46
# Predicted: 50, Actual: 50
# Predicted: 46, Actual: 46
# Predicted: 7, Actual: 29
# Predicted: 11, Actual: 14
# Predicted: 47, Actual: 47
# Predicted: 61, Actual: 54
# Predicted: 27, Actual: 27
# Predicted: 11, Actual: 11
# Predicted: 46, Actual: 46
# Predicted: 61, Actual: 60
# Predicted: 33, Actual: 33
# Predicted: 41, Actual: 41
# Predicted: 28, Actual: 15
# Predicted: 9, Actual: 3
# Predicted: 45, Actual: 19
# Predicted: 57, Actual: 31
# Predicted: 10, Actual: 10
# Predicted: 18, Actual: 18
# Predicted: 23, Actual: 23
# Predicted: 16, Actual: 16
# Predicted: 51, Actual: 51
# Predicted: 44, Actual: 44
# Predicted: 39, Actual: 56
# Predicted: 56, Actual: 56
# Predicted: 51, Actual: 51
# Predicted: 27, Actual: 27
# Predicted: 38, Actual: 40
# Predicted: 5, Actual: 5
# Predicted: 54, Actual: 54
# Predicted: 14, Actual: 14
# Predicted: 37, Actual: 4
# Predicted: 14, Actual: 14
# Predicted: 55, Actual: 14
# Predicted: 6, Actual: 6
# Predicted: 13, Actual: 13
# Predicted: 15, Actual: 15
# Predicted: 31, Actual: 30
# Predicted: 27, Actual: 6
# Predicted: 40, Actual: 40
# Predicted: 4, Actual: 4
# Predicted: 28, Actual: 28
# Predicted: 47, Actual: 1
# Predicted: 3, Actual: 3
# Predicted: 30, Actual: 30
# Predicted: 21, Actual: 1
# Predicted: 20, Actual: 20
# Predicted: 42, Actual: 42
# Predicted: 38, Actual: 38
# Predicted: 7, Actual: 7
# Predicted: 25, Actual: 25
# Predicted: 7, Actual: 7
# Predicted: 22, Actual: 22
# Predicted: 40, Actual: 40
# Predicted: 61, Actual: 35
# Predicted: 5, Actual: 5
# Predicted: 4, Actual: 4
# Predicted: 48, Actual: 48
# Predicted: 37, Actual: 37
# Predicted: 58, Actual: 32
# Predicted: 14, Actual: 14
# Predicted: 32, Actual: 58
# Predicted: 43, Actual: 43
# Predicted: 23, Actual: 58
# Predicted: 9, Actual: 9
# Predicted: 14, Actual: 18
# Predicted: 22, Actual: 22
# Predicted: 17, Actual: 17
# Predicted: 43, Actual: 20
# Predicted: 28, Actual: 3
# Predicted: 9, Actual: 9
# Predicted: 8, Actual: 8
# Predicted: 61, Actual: 61
# Predicted: 29, Actual: 29
# Predicted: 18, Actual: 18
# Predicted: 24, Actual: 13
# Predicted: 53, Actual: 55
# Predicted: 7, Actual: 7
# Predicted: 24, Actual: 24
# Predicted: 47, Actual: 47
# Predicted: 53, Actual: 49
# Predicted: 27, Actual: 27
# Predicted: 25, Actual: 25
# Predicted: 60, Actual: 45
# Predicted: 55, Actual: 55
# Predicted: 39, Actual: 39
# Predicted: 38, Actual: 54
# Predicted: 10, Actual: 10
# Predicted: 46, Actual: 46
# Predicted: 16, Actual: 16
# Predicted: 7, Actual: 7
# Predicted: 3, Actual: 3
# Predicted: 61, Actual: 61
# Predicted: 36, Actual: 36
# Predicted: 36, Actual: 36
# Predicted: 54, Actual: 54
# Predicted: 15, Actual: 15
# Predicted: 5, Actual: 5
# Predicted: 42, Actual: 3
# Predicted: 32, Actual: 32
# Predicted: 1, Actual: 1
# Predicted: 0, Actual: 24
# Predicted: 47, Actual: 47
# Predicted: 19, Actual: 19
# Predicted: 59, Actual: 33
# Predicted: 40, Actual: 40
# Predicted: 5, Actual: 5
# Predicted: 50, Actual: 30
# Predicted: 46, Actual: 20
# Predicted: 5, Actual: 5
# Predicted: 38, Actual: 20
# Predicted: 61, Actual: 61
# Predicted: 50, Actual: 50
# Predicted: 47, Actual: 39
# Predicted: 24, Actual: 12
# Predicted: 24, Actual: 0
# Predicted: 60, Actual: 60
# Predicted: 21, Actual: 20
# Predicted: 44, Actual: 1
# Predicted: 26, Actual: 26
# Predicted: 19, Actual: 5
# Predicted: 33, Actual: 33
# Predicted: 30, Actual: 30
# Predicted: 38, Actual: 38
# Predicted: 60, Actual: 52
# Predicted: 34, Actual: 34
# Predicted: 28, Actual: 8
# Predicted: 21, Actual: 21
# Predicted: 23, Actual: 17
# Predicted: 16, Actual: 16
# Predicted: 61, Actual: 61
# Predicted: 5, Actual: 54
# Predicted: 23, Actual: 23
# Predicted: 52, Actual: 52
# Predicted: 47, Actual: 44
# Predicted: 23, Actual: 23
# Predicted: 26, Actual: 26
# Predicted: 20, Actual: 30
# Predicted: 19, Actual: 7
# Predicted: 46, Actual: 46
# Predicted: 26, Actual: 26
# Predicted: 54, Actual: 28
# Predicted: 36, Actual: 56
# Predicted: 38, Actual: 21
# Predicted: 45, Actual: 45
# Predicted: 61, Actual: 4
# Predicted: 24, Actual: 24
# Predicted: 45, Actual: 45
# Predicted: 15, Actual: 14
# Predicted: 15, Actual: 15
# Predicted: 5, Actual: 5
# Predicted: 43, Actual: 49
# Predicted: 48, Actual: 36
# Predicted: 55, Actual: 55
# Predicted: 2, Actual: 2
# Predicted: 22, Actual: 22
# Predicted: 22, Actual: 22
# Predicted: 50, Actual: 50
# Predicted: 39, Actual: 43
# Predicted: 4, Actual: 4
# Predicted: 1, Actual: 18
# Predicted: 43, Actual: 56
# Predicted: 47, Actual: 18
# Predicted: 20, Actual: 20
# Predicted: 14, Actual: 14
# Predicted: 53, Actual: 10
# Predicted: 61, Actual: 61
# Predicted: 3, Actual: 3
# Predicted: 59, Actual: 59
# Predicted: 28, Actual: 5
# Predicted: 33, Actual: 59
# Predicted: 7, Actual: 7
# Predicted: 0, Actual: 24
# Predicted: 28, Actual: 28
# Predicted: 27, Actual: 43
# Predicted: 53, Actual: 53
# Predicted: 48, Actual: 48
# Predicted: 0, Actual: 0
# Predicted: 48, Actual: 48
# Predicted: 19, Actual: 3
# Predicted: 40, Actual: 40
# Predicted: 59, Actual: 59
# Predicted: 35, Actual: 35
# Predicted: 18, Actual: 18
# Predicted: 42, Actual: 52
# Predicted: 50, Actual: 50
# Predicted: 49, Actual: 49
# Predicted: 53, Actual: 57
# Predicted: 60, Actual: 60
# Predicted: 60, Actual: 60
# Predicted: 52, Actual: 52
# Predicted: 27, Actual: 27
# Predicted: 61, Actual: 61
# Predicted: 41, Actual: 1
# Predicted: 4, Actual: 4
# Predicted: 34, Actual: 34
# Predicted: 32, Actual: 32
# Predicted: 61, Actual: 2
# Predicted: 58, Actual: 58
# Predicted: 15, Actual: 15
# Predicted: 24, Actual: 24
# Predicted: 55, Actual: 4
# Predicted: 42, Actual: 42
# Predicted: 54, Actual: 54
# Predicted: 26, Actual: 26
# Predicted: 42, Actual: 42
# Predicted: 2, Actual: 2
# Predicted: 23, Actual: 23
# Predicted: 43, Actual: 4
# Predicted: 21, Actual: 21
# Predicted: 52, Actual: 9
# Predicted: 53, Actual: 59
# Predicted: 25, Actual: 25
# Predicted: 8, Actual: 8
# Predicted: 12, Actual: 40
# Predicted: 5, Actual: 28
# Predicted: 53, Actual: 49
# Predicted: 35, Actual: 35
# Predicted: 2, Actual: 1
# Predicted: 33, Actual: 60
# Predicted: 10, Actual: 10
# Predicted: 16, Actual: 16
# Predicted: 37, Actual: 37
# Predicted: 14, Actual: 14
# Predicted: 9, Actual: 9
# Predicted: 29, Actual: 29
# Predicted: 18, Actual: 18
# Predicted: 43, Actual: 43
# Predicted: 0, Actual: 2
# Predicted: 20, Actual: 32
# Predicted: 8, Actual: 55
# Predicted: 41, Actual: 54
# Predicted: 55, Actual: 55
# Predicted: 56, Actual: 36
# Predicted: 10, Actual: 10
# Predicted: 17, Actual: 17
# Predicted: 36, Actual: 36
# Predicted: 22, Actual: 31
# Predicted: 4, Actual: 4
# Predicted: 18, Actual: 1
# Predicted: 19, Actual: 19
# Predicted: 14, Actual: 14
# Predicted: 54, Actual: 3
# Predicted: 47, Actual: 47
# Predicted: 33, Actual: 33
# Predicted: 11, Actual: 11
# Predicted: 25, Actual: 25
# Predicted: 26, Actual: 52
# Predicted: 6, Actual: 6
# Predicted: 57, Actual: 31
# Predicted: 40, Actual: 40
# Predicted: 14, Actual: 14
# Predicted: 58, Actual: 58
# Predicted: 52, Actual: 56
# Predicted: 55, Actual: 55
# Predicted: 42, Actual: 42
# Predicted: 53, Actual: 53
# Predicted: 53, Actual: 44
# Predicted: 13, Actual: 13
# Predicted: 50, Actual: 0
# Predicted: 10, Actual: 43
# Predicted: 44, Actual: 44
# Predicted: 50, Actual: 50
# Predicted: 5, Actual: 3
# Predicted: 46, Actual: 43
# Predicted: 8, Actual: 8
# Predicted: 29, Actual: 29
# Predicted: 60, Actual: 34
# Predicted: 20, Actual: 20
# Predicted: 59, Actual: 59
# Predicted: 28, Actual: 6
# Predicted: 52, Actual: 4
# Predicted: 14, Actual: 6
# Predicted: 14, Actual: 14
# Predicted: 2, Actual: 36
# Predicted: 52, Actual: 52
# Predicted: 16, Actual: 16
# Predicted: 29, Actual: 29
# Predicted: 55, Actual: 55
# Predicted: 43, Actual: 43
# Predicted: 25, Actual: 25
# Predicted: 8, Actual: 11
# Predicted: 8, Actual: 8
# Predicted: 60, Actual: 60
# Predicted: 10, Actual: 10
# Predicted: 13, Actual: 13
# Predicted: 7, Actual: 7
# Predicted: 44, Actual: 44
# Predicted: 44, Actual: 21
# Predicted: 59, Actual: 33
# Predicted: 29, Actual: 29
# Predicted: 43, Actual: 43
# Predicted: 58, Actual: 32
# Predicted: 13, Actual: 0
# Predicted: 22, Actual: 22
# Predicted: 42, Actual: 11
# Predicted: 61, Actual: 59
# Predicted: 53, Actual: 36
# Predicted: 26, Actual: 26
# Predicted: 42, Actual: 42
# Predicted: 22, Actual: 17
# Predicted: 7, Actual: 7
# Predicted: 10, Actual: 10
# Predicted: 31, Actual: 31
# Predicted: 48, Actual: 48
# Predicted: 35, Actual: 35
# Predicted: 3, Actual: 3
# Predicted: 48, Actual: 55
# Predicted: 36, Actual: 26
# Predicted: 41, Actual: 6
# Predicted: 17, Actual: 4
# Predicted: 56, Actual: 56
# Predicted: 8, Actual: 61
# Predicted: 54, Actual: 28
# Predicted: 9, Actual: 9
# Predicted: 46, Actual: 46
# Predicted: 2, Actual: 2
# Predicted: 11, Actual: 11
# Predicted: 8, Actual: 3
# Predicted: 5, Actual: 5
# Predicted: 47, Actual: 18
# Predicted: 15, Actual: 15
# Predicted: 34, Actual: 60
# Predicted: 18, Actual: 18
# Predicted: 8, Actual: 8
# Predicted: 23, Actual: 23
# Predicted: 61, Actual: 61
# Predicted: 0, Actual: 0
# Predicted: 5, Actual: 3
# Predicted: 11, Actual: 11
# Predicted: 7, Actual: 7
# Predicted: 38, Actual: 38
# Predicted: 61, Actual: 61
# Predicted: 4, Actual: 4
# Predicted: 51, Actual: 51
# Predicted: 39, Actual: 10
# Predicted: 59, Actual: 59
# Predicted: 22, Actual: 17
# Predicted: 7, Actual: 9
# Predicted: 25, Actual: 23
# Predicted: 16, Actual: 16
# Predicted: 34, Actual: 34
# Predicted: 10, Actual: 10
# Predicted: 56, Actual: 56
# Predicted: 42, Actual: 8
# Predicted: 18, Actual: 44
# Predicted: 29, Actual: 7
# Predicted: 54, Actual: 8
# Predicted: 7, Actual: 25
# Predicted: 47, Actual: 18
# Predicted: 21, Actual: 21
# Predicted: 58, Actual: 58
# Predicted: 3, Actual: 13
# Predicted: 53, Actual: 53
# Predicted: 19, Actual: 7
# Predicted: 5, Actual: 54
# Predicted: 6, Actual: 6
# Predicted: 54, Actual: 54
# Predicted: 60, Actual: 60
# Predicted: 53, Actual: 15
# Predicted: 3, Actual: 3
# Predicted: 45, Actual: 52
# Predicted: 27, Actual: 27
# Predicted: 27, Actual: 34
# Predicted: 47, Actual: 47
# Predicted: 13, Actual: 13
# Predicted: 33, Actual: 33
# Predicted: 14, Actual: 14
# Predicted: 44, Actual: 21
# Predicted: 42, Actual: 42
# Predicted: 58, Actual: 48
# Predicted: 12, Actual: 38
# Predicted: 5, Actual: 5
# Predicted: 30, Actual: 30
# Predicted: 22, Actual: 17
# Predicted: 4, Actual: 4
# Predicted: 47, Actual: 1
# Predicted: 50, Actual: 50
# Predicted: 35, Actual: 35
# Predicted: 41, Actual: 41
# Predicted: 58, Actual: 59
# Predicted: 34, Actual: 34
# Predicted: 33, Actual: 53
# Predicted: 29, Actual: 29
# Predicted: 18, Actual: 47
# Predicted: 44, Actual: 44
# Predicted: 36, Actual: 36
# Predicted: 61, Actual: 35
# Predicted: 42, Actual: 42
# Predicted: 18, Actual: 18
# Predicted: 52, Actual: 27
# Predicted: 52, Actual: 8
# Predicted: 49, Actual: 49
# Predicted: 17, Actual: 17
# Predicted: 35, Actual: 35
# Predicted: 47, Actual: 39
# Predicted: 2, Actual: 46
# Predicted: 15, Actual: 15
# Predicted: 47, Actual: 47
# Predicted: 47, Actual: 44
# Predicted: 26, Actual: 56
# Predicted: 31, Actual: 31
# Predicted: 15, Actual: 15
# Predicted: 30, Actual: 30
# Predicted: 26, Actual: 26
# Predicted: 18, Actual: 18
# Predicted: 5, Actual: 5
# Predicted: 0, Actual: 51
# Predicted: 2, Actual: 9
# Predicted: 37, Actual: 37
# Predicted: 47, Actual: 47
# Predicted: 39, Actual: 39
# Predicted: 54, Actual: 28
# Predicted: 20, Actual: 54
# Predicted: 56, Actual: 56
# Predicted: 59, Actual: 59
# Predicted: 5, Actual: 28
# Predicted: 24, Actual: 26
# Predicted: 30, Actual: 30
# Predicted: 36, Actual: 36
# Predicted: 53, Actual: 33
# Predicted: 35, Actual: 35
# Predicted: 9, Actual: 25
# Predicted: 0, Actual: 0
# Predicted: 48, Actual: 58
# Predicted: 35, Actual: 35
# Predicted: 24, Actual: 24
# Predicted: 49, Actual: 49
# Predicted: 36, Actual: 36
# Predicted: 45, Actual: 45
# Predicted: 1, Actual: 1
# Predicted: 51, Actual: 51
# Predicted: 23, Actual: 31
# Predicted: 50, Actual: 50
# Predicted: 20, Actual: 17
# Predicted: 16, Actual: 16
# Predicted: 0, Actual: 0
# Predicted: 48, Actual: 48
# Predicted: 44, Actual: 44
# Predicted: 34, Actual: 34
# Predicted: 57, Actual: 57
# Predicted: 6, Actual: 6
# Predicted: 38, Actual: 39
# Predicted: 61, Actual: 59
# Predicted: 31, Actual: 57
# Predicted: 44, Actual: 44
# Predicted: 24, Actual: 24
# Predicted: 53, Actual: 53
# Predicted: 30, Actual: 30
# Predicted: 53, Actual: 53
# Predicted: 45, Actual: 42
# Predicted: 33, Actual: 33
# Predicted: 36, Actual: 36
# Predicted: 38, Actual: 12
# Predicted: 12, Actual: 38
# Predicted: 24, Actual: 9
# Predicted: 3, Actual: 3
# Predicted: 7, Actual: 7
# Predicted: 17, Actual: 17
# Predicted: 45, Actual: 45
# Predicted: 42, Actual: 42
# Predicted: 15, Actual: 15
# Predicted: 12, Actual: 12
# Predicted: 50, Actual: 48
# Predicted: 3, Actual: 5
# Predicted: 40, Actual: 40
# Predicted: 60, Actual: 60
# Predicted: 22, Actual: 22
# Predicted: 5, Actual: 3
# Predicted: 14, Actual: 14
# Predicted: 14, Actual: 38
# Predicted: 25, Actual: 25
# Predicted: 30, Actual: 30
# Predicted: 6, Actual: 6
# Predicted: 2, Actual: 35
# Predicted: 10, Actual: 10
# Predicted: 37, Actual: 37
# Predicted: 28, Actual: 28
# Predicted: 8, Actual: 54
# Predicted: 18, Actual: 18
# Predicted: 12, Actual: 12
# Predicted: 33, Actual: 33
# Predicted: 21, Actual: 21
# Predicted: 2, Actual: 2
# Predicted: 54, Actual: 54
# Predicted: 20, Actual: 20
# Predicted: 40, Actual: 40
# Predicted: 8, Actual: 8
# Predicted: 41, Actual: 41
# Predicted: 15, Actual: 15
# Predicted: 23, Actual: 49
# Predicted: 34, Actual: 34
# Predicted: 30, Actual: 30
# Predicted: 5, Actual: 3
# Predicted: 7, Actual: 9
# Predicted: 22, Actual: 22
# Predicted: 37, Actual: 37
# Predicted: 33, Actual: 59
# Predicted: 12, Actual: 12
# Predicted: 17, Actual: 17
# Predicted: 10, Actual: 10
# Predicted: 31, Actual: 31
# Predicted: 43, Actual: 46
# Predicted: 26, Actual: 26
# Predicted: 11, Actual: 11
# Predicted: 36, Actual: 40
# Predicted: 11, Actual: 11
# Predicted: 33, Actual: 33
# Predicted: 35, Actual: 35
# Predicted: 2, Actual: 2
# Predicted: 18, Actual: 18
# Predicted: 20, Actual: 20
# Predicted: 15, Actual: 15
# Predicted: 47, Actual: 21
# Predicted: 54, Actual: 36
# Predicted: 9, Actual: 9
# Predicted: 53, Actual: 51
# Predicted: 41, Actual: 41
# Predicted: 10, Actual: 10
# Predicted: 13, Actual: 13
# Predicted: 40, Actual: 36
# Predicted: 40, Actual: 40
# Predicted: 11, Actual: 11
# Predicted: 26, Actual: 26
# Predicted: 56, Actual: 56
# Predicted: 8, Actual: 54
# Predicted: 31, Actual: 31
# Predicted: 32, Actual: 32
# Predicted: 50, Actual: 58
# Predicted: 10, Actual: 10
# Predicted: 33, Actual: 33
# Predicted: 20, Actual: 20
# Predicted: 18, Actual: 1
# Predicted: 57, Actual: 0
# Predicted: 57, Actual: 32
# Predicted: 41, Actual: 19
# Predicted: 32, Actual: 32
# Predicted: 55, Actual: 55
# Predicted: 24, Actual: 50
# Predicted: 16, Actual: 16
# Predicted: 14, Actual: 14
# Predicted: 46, Actual: 46
# Predicted: 58, Actual: 58
# Predicted: 51, Actual: 51
# Predicted: 34, Actual: 34
# Predicted: 49, Actual: 22
# Predicted: 10, Actual: 10
# Predicted: 28, Actual: 28
# Predicted: 0, Actual: 24
